# %% [markdown]
# ## Linear progression multi dimentional

# %%
from ds_discovery import Transition
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
tr = Transition.from_memory()
tr.set_source_uri("https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/linear_regression_class/data_2d.csv", header=None)
df = tr.load_source_canonical()

# %%
sub = df.loc[:,[0,1]]
sub[2] = 1
sub.head()
# Out:
#            0          1  2
# 0  17.930201  94.520592  1
# 1  97.144697  69.593282  1
# 2  81.775901   5.737648  1
# 3  55.854342  70.325902  1
# 4  49.366550  75.114040  1

# %%
X = sub.to_numpy()
Y = df[2].to_numpy()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)
plt.show()

# %% [markdown]
# ### Calculate the weight using numpy

# %% [markdown]
# $$ \text{weight} = \left(X^TX\right)^{-1}X^Ty  $$
#
# where $ X = N \cdot D $

# %%
# apply the equations we learned to calculate a and b
# numpy has a special method for solving Ax = b
# so we don't use x = inv(A)*b
# note: the * operator does element-by-element multiplication in numpy
#       np.dot() does what we expect for matrix multiplication
w = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, Y))
Yhat = np.dot(X, w)

# %% [markdown]
# $$ \text{sum of squared residule} = \sum_i \left( y_i - \hat y_i \right)^2 $$

# %%
d1 = Y - Yhat
ssr = d1.dot(d1)

# %% [markdown]
# $$ \text{sum of squared total} = \sum_i \left( y_i - \bar y_i \right)^2 $$

# %%
d2 = Y - Y.mean()
sst = d2.dot(d2)

# %% [markdown]
# $$ R^2 = 1 - \frac{SSres}{SStot}  $$

# %%
# calculating r-squared
r2 = 1 - ssr/sst
print(f"The r-squared is: {r2}")
# Out:
# The r-squared is: 0.9980040612475777
