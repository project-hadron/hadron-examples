# %% [markdown]
# <cite>Darryl Oatridge, August 2022<cite>

# %% [markdown]
#  ## Validation of Data
#
# - The review of a dataset by an expert with similar credentials and subject knowledge as the data creator to validate the accuracy of the data.

# %%
from ds_discovery import Transition

# %% [markdown]
# ## Quality Assurance
#
# Quality assurance provides an immediate insight into the quality, quantity, verasity and availability of the dataset being provided. This is a critical step to the success of any machine learning or product outcome.
#
# Observational immediacy to the content of the dataset allows quick decision making at the earliest stage of the process. It also provides output for discussion for SME's and data architects to share common reports that are based on best practice and familiar to both parties.
#
# Finially it provides observational tools presenting a broad-set of information in a compacted and common display format.

# %%
tr = Transition.from_env('demo_quality', has_contract=False)

# %% [markdown]
# #### Set File Source
# Initially we set the file source for our data of interest and run the component.

# %%
## Set the file source location
data = 'https://www.openml.org/data/get_csv/16826755/phpMYEkMl.csv'
tr.set_source_uri(data)
tr.set_persist()
tr.set_description("Original Titanic Dataset")

# %% [markdown]
# ### Data Dictionary
#
# The data dictionary is a go to tool that gives both a visual and shareable summary of the dataset provided. In this case one looks at the raw source so as to assess its visual suitability.
#
# In this instance, taking the original Titanic dataset, data elements such as nulls have been masked and in some cases inappropriately 'typed' the data. There are also multiple features that are not required, all of which need to be dealt with before one can get a better view of the data presented.

# %%
df = tr.load_source_canonical()
tr.canonical_report (df)
# Out:
# <style type="text/css">
# #T_ad7e4 th {
#   font-size: 120%;
#   text-align: center;
# }
# #T_ad7e4 .row_heading {
#   display: none;;
# }
# #T_ad7e4  .blank {
#   display: none;;
# }
# #T_ad7e4_row0_col0, #T_ad7e4_row1_col0, #T_ad7e4_row2_col0, #T_ad7e4_row3_col0, #T_ad7e4_row4_col0, #T_ad7e4_row5_col0, #T_ad7e4_row6_col0, #T_ad7e4_row7_col0, #T_ad7e4_row8_col0, #T_ad7e4_row9_col0, #T_ad7e4_row10_col0, #T_ad7e4_row11_col0, #T_ad7e4_row12_col0, #T_ad7e4_row13_col0 {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_ad7e4_row0_col2, #T_ad7e4_row0_col3, #T_ad7e4_row1_col2, #T_ad7e4_row1_col3, #T_ad7e4_row2_col2, #T_ad7e4_row2_col5, #T_ad7e4_row3_col2, #T_ad7e4_row3_col5, #T_ad7e4_row4_col2, #T_ad7e4_row5_col2, #T_ad7e4_row5_col3, #T_ad7e4_row5_col5, #T_ad7e4_row6_col2, #T_ad7e4_row6_col3, #T_ad7e4_row6_col5, #T_ad7e4_row7_col2, #T_ad7e4_row7_col3, #T_ad7e4_row7_col5, #T_ad7e4_row8_col2, #T_ad7e4_row9_col2, #T_ad7e4_row9_col3, #T_ad7e4_row10_col2, #T_ad7e4_row10_col3, #T_ad7e4_row11_col2, #T_ad7e4_row12_col2, #T_ad7e4_row12_col3, #T_ad7e4_row13_col2, #T_ad7e4_row13_col3, #T_ad7e4_row13_col5 {
#   color: black;
# }
# #T_ad7e4_row0_col5 {
#   background-color: #f0f9ed;
#   color: black;
# }
# #T_ad7e4_row1_col5 {
#   background-color: #e5f5e0;
#   color: black;
# }
# #T_ad7e4_row2_col3 {
#   background-color: #fcb499;
#   color: black;
# }
# #T_ad7e4_row3_col3, #T_ad7e4_row4_col3, #T_ad7e4_row8_col3, #T_ad7e4_row11_col3 {
#   background-color: #ffede5;
#   color: black;
# }
# #T_ad7e4_row4_col5, #T_ad7e4_row9_col5 {
#   background-color: #84cc83;
#   color: black;
# }
# #T_ad7e4_row8_col1, #T_ad7e4_row9_col1, #T_ad7e4_row11_col1, #T_ad7e4_row12_col1 {
#   color: #0f398a;
# }
# #T_ad7e4_row8_col5, #T_ad7e4_row11_col5 {
#   background-color: #a4da9e;
#   color: black;
# }
# #T_ad7e4_row10_col5, #T_ad7e4_row12_col5 {
#   background-color: #a1cbe2;
#   color: black;
# }
# </style>
# <table id="T_ad7e4">
#   <caption>%_Dom: The % most dominant element </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad7e4_level0_col0" class="col_heading level0 col0" >Attributes (14)</th>
#       <th id="T_ad7e4_level0_col1" class="col_heading level0 col1" >dType</th>
#       <th id="T_ad7e4_level0_col2" class="col_heading level0 col2" >%_Null</th>
#       <th id="T_ad7e4_level0_col3" class="col_heading level0 col3" >%_Dom</th>
#       <th id="T_ad7e4_level0_col4" class="col_heading level0 col4" >Count</th>
#       <th id="T_ad7e4_level0_col5" class="col_heading level0 col5" >Unique</th>
#       <th id="T_ad7e4_level0_col6" class="col_heading level0 col6" >Observations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad7e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad7e4_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_ad7e4_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_ad7e4_row0_col2" class="data row0 col2" >0.0%</td>
#       <td id="T_ad7e4_row0_col3" class="data row0 col3" >20.1%</td>
#       <td id="T_ad7e4_row0_col4" class="data row0 col4" >1309</td>
#       <td id="T_ad7e4_row0_col5" class="data row0 col5" >99</td>
#       <td id="T_ad7e4_row0_col6" class="data row0 col6" >Sample: ? | 24 | 22 | 21 | 30</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad7e4_row1_col0" class="data row1 col0" >boat</td>
#       <td id="T_ad7e4_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_ad7e4_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_ad7e4_row1_col3" class="data row1 col3" >62.9%</td>
#       <td id="T_ad7e4_row1_col4" class="data row1 col4" >1309</td>
#       <td id="T_ad7e4_row1_col5" class="data row1 col5" >28</td>
#       <td id="T_ad7e4_row1_col6" class="data row1 col6" >Sample: ? | 13 | C | 15 | 14</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad7e4_row2_col0" class="data row2 col0" >body</td>
#       <td id="T_ad7e4_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_ad7e4_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_ad7e4_row2_col3" class="data row2 col3" >90.8%</td>
#       <td id="T_ad7e4_row2_col4" class="data row2 col4" >1309</td>
#       <td id="T_ad7e4_row2_col5" class="data row2 col5" >122</td>
#       <td id="T_ad7e4_row2_col6" class="data row2 col6" >Sample: ? | 58 | 285 | 156 | 143</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad7e4_row3_col0" class="data row3 col0" >cabin</td>
#       <td id="T_ad7e4_row3_col1" class="data row3 col1" >object</td>
#       <td id="T_ad7e4_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_ad7e4_row3_col3" class="data row3 col3" >77.5%</td>
#       <td id="T_ad7e4_row3_col4" class="data row3 col4" >1309</td>
#       <td id="T_ad7e4_row3_col5" class="data row3 col5" >187</td>
#       <td id="T_ad7e4_row3_col6" class="data row3 col6" >Sample: ? | C23 C25 C27 | G6 | B57 B59 B63 B66 | C22 C26</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad7e4_row4_col0" class="data row4 col0" >embarked</td>
#       <td id="T_ad7e4_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_ad7e4_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_ad7e4_row4_col3" class="data row4 col3" >69.8%</td>
#       <td id="T_ad7e4_row4_col4" class="data row4 col4" >1309</td>
#       <td id="T_ad7e4_row4_col5" class="data row4 col5" >4</td>
#       <td id="T_ad7e4_row4_col6" class="data row4 col6" >Sample: S | C | Q | ?</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad7e4_row5_col0" class="data row5 col0" >fare</td>
#       <td id="T_ad7e4_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_ad7e4_row5_col2" class="data row5 col2" >0.0%</td>
#       <td id="T_ad7e4_row5_col3" class="data row5 col3" >4.6%</td>
#       <td id="T_ad7e4_row5_col4" class="data row5 col4" >1309</td>
#       <td id="T_ad7e4_row5_col5" class="data row5 col5" >282</td>
#       <td id="T_ad7e4_row5_col6" class="data row5 col6" >Sample: 8.05 | 13 | 7.75 | 26 | 7.8958</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad7e4_row6_col0" class="data row6 col0" >home.dest</td>
#       <td id="T_ad7e4_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_ad7e4_row6_col2" class="data row6 col2" >0.0%</td>
#       <td id="T_ad7e4_row6_col3" class="data row6 col3" >43.1%</td>
#       <td id="T_ad7e4_row6_col4" class="data row6 col4" >1309</td>
#       <td id="T_ad7e4_row6_col5" class="data row6 col5" >370</td>
#       <td id="T_ad7e4_row6_col6" class="data row6 col6" >Sample: ? | New York, NY | London | Montreal, PQ | Paris, France</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad7e4_row7_col0" class="data row7 col0" >name</td>
#       <td id="T_ad7e4_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_ad7e4_row7_col2" class="data row7 col2" >0.0%</td>
#       <td id="T_ad7e4_row7_col3" class="data row7 col3" >0.2%</td>
#       <td id="T_ad7e4_row7_col4" class="data row7 col4" >1309</td>
#       <td id="T_ad7e4_row7_col5" class="data row7 col5" >1307</td>
#       <td id="T_ad7e4_row7_col6" class="data row7 col6" >Sample: Connolly, Miss. Kate | Kelly, Mr. James | Allen, Miss. Elisabeth Walton | Ilmakangas, Miss. ...</td>
#     </tr>
#     <tr>
#       <th id="T_ad7e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad7e4_row8_col0" class="data row8 col0" >parch</td>
#       <td id="T_ad7e4_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_ad7e4_row8_col2" class="data row8 col2" >0.0%</td>
#       <td id="T_ad7e4_row8_col3" class="data row8 col3" >76.5%</td>
#       <td id="T_ad7e4_row8_col4" class="data row8 col4" >1309</td>
#       <td id="T_ad7e4_row8_col5" class="data row8 col5" >8</td>
#       <td id="T_ad7e4_row8_col6" class="data row8 col6" >max=9 | min=0 | mean=0.39 | dominant=0</

# %% [markdown]
# #### Engineering Selection
#
# The canonical is tidied up through engineering selection where one adjusts the features of interest, whilst removing the data columns that are of no interest and making sure the data is correctly typed.

# %%
df = tr.tools.auto_reinstate_nulls(df, nulls_list=['?'])
df = tr.tools.to_remove(df, headers=['body', 'name', 'ticket', 'boat', 'home.dest'])
df = tr.tools.auto_to_category(df)
df = tr.tools.to_numeric_type(df, headers=['age', 'fare'])
df = tr.tools.to_int_type(df, headers='survived')

tr.run_component_pipeline()

# %% [markdown]
# ### Validation
#
# Now our selection engineering has been applied to the dataset one has a clearer view of the value of the data provided.
#
# The canonical report provides an enhancment of already existing data science tools to give a clear single view of our data set that is familuar to a broader audience.

# %%
tr.canonical_report(df)
# Out:
# <style type="text/css">
# #T_640f1 th {
#   font-size: 120%;
#   text-align: center;
# }
# #T_640f1 .row_heading {
#   display: none;;
# }
# #T_640f1  .blank {
#   display: none;;
# }
# #T_640f1_row0_col0, #T_640f1_row1_col0, #T_640f1_row2_col0, #T_640f1_row3_col0, #T_640f1_row4_col0, #T_640f1_row5_col0, #T_640f1_row6_col0, #T_640f1_row7_col0, #T_640f1_row8_col0 {
#   font-weight: bold;
#   font-size: 120%;
# }
# #T_640f1_row0_col1, #T_640f1_row3_col1 {
#   color: #2f0f8a;
# }
# #T_640f1_row0_col2, #T_640f1_row0_col3, #T_640f1_row1_col5, #T_640f1_row2_col2, #T_640f1_row3_col2, #T_640f1_row3_col3, #T_640f1_row3_col5, #T_640f1_row4_col2, #T_640f1_row5_col2, #T_640f1_row5_col3, #T_640f1_row6_col2, #T_640f1_row6_col3, #T_640f1_row7_col2, #T_640f1_row8_col2, #T_640f1_row8_col3 {
#   color: black;
# }
# #T_640f1_row0_col5 {
#   background-color: #f0f9ed;
#   color: black;
# }
# #T_640f1_row1_col2, #T_640f1_row1_col3, #T_640f1_row2_col3, #T_640f1_row4_col3, #T_640f1_row7_col3 {
#   background-color: #ffede5;
#   color: black;
# }
# #T_640f1_row2_col1, #T_640f1_row4_col1, #T_640f1_row5_col1, #T_640f1_row6_col1, #T_640f1_row7_col1 {
#   color: #208a0f;
# }
# #T_640f1_row2_col5, #T_640f1_row5_col5 {
#   background-color: #84cc83;
#   color: black;
# }
# #T_640f1_row4_col5, #T_640f1_row7_col5 {
#   background-color: #a4da9e;
#   color: black;
# }
# #T_640f1_row6_col5, #T_640f1_row8_col5 {
#   background-color: #a1cbe2;
#   color: black;
# }
# #T_640f1_row8_col1 {
#   color: #0f398a;
# }
# </style>
# <table id="T_640f1">
#   <caption>%_Dom: The % most dominant element </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_640f1_level0_col0" class="col_heading level0 col0" >Attributes (9)</th>
#       <th id="T_640f1_level0_col1" class="col_heading level0 col1" >dType</th>
#       <th id="T_640f1_level0_col2" class="col_heading level0 col2" >%_Null</th>
#       <th id="T_640f1_level0_col3" class="col_heading level0 col3" >%_Dom</th>
#       <th id="T_640f1_level0_col4" class="col_heading level0 col4" >Count</th>
#       <th id="T_640f1_level0_col5" class="col_heading level0 col5" >Unique</th>
#       <th id="T_640f1_level0_col6" class="col_heading level0 col6" >Observations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_640f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_640f1_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_640f1_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_640f1_row0_col2" class="data row0 col2" >20.1%</td>
#       <td id="T_640f1_row0_col3" class="data row0 col3" >20.1%</td>
#       <td id="T_640f1_row0_col4" class="data row0 col4" >1309</td>
#       <td id="T_640f1_row0_col5" class="data row0 col5" >99</td>
#       <td id="T_640f1_row0_col6" class="data row0 col6" >max=80.0 | min=0.1667 | mean=29.88 | dominant=24.0</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_640f1_row1_col0" class="data row1 col0" >cabin</td>
#       <td id="T_640f1_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_640f1_row1_col2" class="data row1 col2" >77.5%</td>
#       <td id="T_640f1_row1_col3" class="data row1 col3" >77.5%</td>
#       <td id="T_640f1_row1_col4" class="data row1 col4" >1309</td>
#       <td id="T_640f1_row1_col5" class="data row1 col5" >187</td>
#       <td id="T_640f1_row1_col6" class="data row1 col6" >Sample: C23 C25 C27 | G6 | B57 B59 B63 B66 | F4 | F33</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_640f1_row2_col0" class="data row2 col0" >embarked</td>
#       <td id="T_640f1_row2_col1" class="data row2 col1" >category</td>
#       <td id="T_640f1_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_640f1_row2_col3" class="data row2 col3" >69.8%</td>
#       <td id="T_640f1_row2_col4" class="data row2 col4" >1309</td>
#       <td id="T_640f1_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_640f1_row2_col6" class="data row2 col6" >Sample: S | C | Q | nan</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_640f1_row3_col0" class="data row3 col0" >fare</td>
#       <td id="T_640f1_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_640f1_row3_col2" class="data row3 col2" >0.1%</td>
#       <td id="T_640f1_row3_col3" class="data row3 col3" >4.6%</td>
#       <td id="T_640f1_row3_col4" class="data row3 col4" >1309</td>
#       <td id="T_640f1_row3_col5" class="data row3 col5" >282</td>
#       <td id="T_640f1_row3_col6" class="data row3 col6" >max=512.3292 | min=0.0 | mean=33.3 | dominant=8.05</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_640f1_row4_col0" class="data row4 col0" >parch</td>
#       <td id="T_640f1_row4_col1" class="data row4 col1" >category</td>
#       <td id="T_640f1_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_640f1_row4_col3" class="data row4 col3" >76.5%</td>
#       <td id="T_640f1_row4_col4" class="data row4 col4" >1309</td>
#       <td id="T_640f1_row4_col5" class="data row4 col5" >8</td>
#       <td id="T_640f1_row4_col6" class="data row4 col6" >Sample: 0 | 1 | 2 | 3 | 4</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_640f1_row5_col0" class="data row5 col0" >pclass</td>
#       <td id="T_640f1_row5_col1" class="data row5 col1" >category</td>
#       <td id="T_640f1_row5_col2" class="data row5 col2" >0.0%</td>
#       <td id="T_640f1_row5_col3" class="data row5 col3" >54.2%</td>
#       <td id="T_640f1_row5_col4" class="data row5 col4" >1309</td>
#       <td id="T_640f1_row5_col5" class="data row5 col5" >3</td>
#       <td id="T_640f1_row5_col6" class="data row5 col6" >Sample: 3 | 1 | 2</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_640f1_row6_col0" class="data row6 col0" >sex</td>
#       <td id="T_640f1_row6_col1" class="data row6 col1" >category</td>
#       <td id="T_640f1_row6_col2" class="data row6 col2" >0.0%</td>
#       <td id="T_640f1_row6_col3" class="data row6 col3" >64.4%</td>
#       <td id="T_640f1_row6_col4" class="data row6 col4" >1309</td>
#       <td id="T_640f1_row6_col5" class="data row6 col5" >2</td>
#       <td id="T_640f1_row6_col6" class="data row6 col6" >Sample: male | female</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_640f1_row7_col0" class="data row7 col0" >sibsp</td>
#       <td id="T_640f1_row7_col1" class="data row7 col1" >category</td>
#       <td id="T_640f1_row7_col2" class="data row7 col2" >0.0%</td>
#       <td id="T_640f1_row7_col3" class="data row7 col3" >68.1%</td>
#       <td id="T_640f1_row7_col4" class="data row7 col4" >1309</td>
#       <td id="T_640f1_row7_col5" class="data row7 col5" >7</td>
#       <td id="T_640f1_row7_col6" class="data row7 col6" >Sample: 0 | 1 | 2 | 4 | 3</td>
#     </tr>
#     <tr>
#       <th id="T_640f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_640f1_row8_col0" class="data row8 col0" >survived</td>
#       <td id="T_640f1_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_640f1_row8_col2" class="data row8 col2" >0.0%</td>
#       <td id="T_640f1_row8_col3" class="data row8 col3" >61.8%</td>
#       <td id="T_640f1_row8_col4" class="data row8 col4" >1309</td>
#       <td id="T_640f1_row8_col5" class="data row8 col5" >2</td>
#       <td id="T_640f1_row8_col6" class="data row8 col6" >max=1 | min=0 | mean=0.38 | dominant=0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Reporting
#
# As well as its visual display the enhanced dictionary can be distributed to any connecting service, such as an XL spreadsheet and its graphical tooling.

# %%
dictionary = tr.canonical_report(tr.load_persist_canonical(), stylise=False)
tr.save_report_canonical(reports=tr.REPORT_DICTIONARY, report_canonical=dictionary)

# %% [markdown]
# ### Report Tailoring
#
# By default reports are given their own name and data type, though this can be tailored to suit a targeted system with options of name, versioning, timestamp and the data type of the data to be reported.

# %%
reports = [tr.report2dict(report=tr.REPORT_DICTIONARY, prefix='titanic_', file_type='csv', stamped='days')]
tr.save_report_canonical(reports=reports, report_canonical=dictionary)

# %% [markdown]
# ## Quality Summary
#
# When looking at the data as well as the detail in the dictionary one can also produce a summary overview of the dataset as a whole. The quality report provides a subset view of quality score, data shape, data types, usability summary and cost, if applicable.

# %%
tr.report_quality_summary()
# Out:
#         report              summary    result
# 0        score          quality_avg       75%
# 1                     usability_avg      100%
# 2               provenance_complete        0%
# 3                    data_described        0%
# 4   data_shape                 rows      1309
# 5                           columns        14
# 6                            memory  593.08KB
# 7    data_type              numeric         0
# 8                          category         6
# 9                          datetime         0
# 10                             bool         1
# 11                           others         7
# 12   usability          mostly_null         0
# 13                     predominance         0
# 14                       correlated         0
# 15                      adjustments         5
# 16        cost                price        NA

# %% [markdown]
# ### Report
#
# As with the dictionary the quality report can be saved and redistributed to interested parties.

# %%
quality = tr.report_quality_summary(stylise=False)
tr.save_report_canonical(reports=tr.REPORT_SUMMARY, report_canonical=quality)
